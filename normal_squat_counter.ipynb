# %%
import os
import numpy as np
import json
import matplotlib.pyplot as plt
from scipy import ndimage

# %%
folder_path='/content/drive/MyDrive/keypoints_from_videos_json/squat/'

# %%
def angle_between_points(a, b, c):

    a = np.array(a)
    b = np.array(b)
    c = np.array(c)
    ba = a - b
    bc = c - b

    cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    angle = np.arccos(cosine_angle)

    return np.degrees(angle)

# %%
#check for width and height should be multiple of 16

count_of_squats = 0
squat_pos = 0
prev_squat_pos = 0
angles_list=[]
# i = 0
for json_file in os.listdir(folder_path):
  # print(json_file)
  f=open(folder_path+json_file,)
  raw_json=json.load(f)
  x=list(raw_json.items())[1][1][0]['pose_keypoints_2d']
  x=np.array(x).reshape(18,3)
  # print(x)
  f.close()
  try:
    # calculate left leg angle
    # center_11=int(x[11][0]*1920),int(x[11][1]*1080)#left hip value
    # center_12=int(x[12][0]*1920),int(x[12][1]*1080)#left knee value
    # center_13=int(x[13][0]*1920),int(x[13][1]*1080)#left ankle value
    center_11=int(x[11][0]),int(x[11][1])#left hip value
    center_12=int(x[12][0]),int(x[12][1])#left knee value
    center_13=int(x[13][0]),int(x[13][1])#left ankle value

    #check for squat
    squat_left_angle = int(angle_between_points(center_11, center_12, center_13))
    
    squat_pos = 1 if squat_left_angle <= 85 else 0
    if prev_squat_pos - squat_pos == 1:
      count_of_squats +=1

    prev_squat_pos = squat_pos

    print(squat_left_angle, squat_pos, count_of_squats)

    angles_list.append(squat_left_angle)
  except:
    pass
# Out:
# 167 0 0
# 167 0 0
# 167 0 0
# 167 0 0
# 167 0 0
# 169 0 0
# 167 0 0
# 167 0 0
# 166 0 0
# 167 0 0
# 168 0 0
# 165 0 0
# 167 0 0
# 165 0 0
# 166 0 0
# 168 0 0
# 166 0 0
# 168 0 0
# 168 0 0
# 168 0 0
# 168 0 0
# 168 0 0
# 170 0 0
# 170 0 0
# 170 0 0
# 170 0 0
# 170 0 0
# 170 0 0
# 170 0 0
# 170 0 0
# 172 0 0
# 172 0 0
# 170 0 0
# 170 0 0
# 170 0 0
# 170 0 0
# 170 0 0
# 170 0 0
# 170 0 0
# 170 0 0
# 170 0 0
# 170 0 0
# 170 0 0
# 170 0 0
# 170 0 0
# 170 0 0
# 173 0 0
# 173 0 0
# 174 0 0
# 175 0 0
# 174 0 0
# 176 0 0
# 178 0 0
# 179 0 0
# 180 0 0
# 177 0 0
# 171 0 0
# 169 0 0
# 161 0 0
# 161 0 0
# 157 0 0
# 156 0 0
# 151 0 0
# 151 0 0
# 148 0 0
# 144 0 0
# 141 0 0
# 138 0 0
# 133 0 0
# 131 0 0
# 129 0 0
# 125 0 0
# 122 0 0
# 122 0 0
# 119 0 0
# 115 0 0
# 113 0 0
# 111 0 0
# 109 0 0
# 104 0 0
# 103 0 0
# 100 0 0
# 99 0 0
# 96 0 0
# 92 0 0
# 89 0 0
# 91 0 0
# 89 0 0
# 86 0 0
# 88 0 0
# 86 0 0
# 87 0 0
# 85 1 0
# 86 0 1
# 88 0 1
# 91 0 1
# 92 0 1
# 93 0 1
# 93 0 1
# 95 0 1
# 100 0 1
# 103 0 1
# 105 0 1
# 110 0 1
# 112 0 1
# 114 0 1
# 119 0 1
# 122 0 1
# 125 0 1
# 130 0 1
# 133 0 1
# 138 0 1
# 142 0 1
# 148 0 1
# 152 0 1
# 153 0 1
# 157 0 1
# 160 0 1
# 167 0 1
# 171 0 1
# 174 0 1
# 175 0 1
# 177 0 1
# 179 0 1
# 177 0 1
# 174 0 1
# 172 0 1
# 172 0 1
# 171 0 1
# 170 0 1
# 171 0 1
# 171 0 1
# 171 0 1
# 171 0 1
# 173 0 1
# 173 0 1
# 174 0 1
# 177 0 1
# 179 0 1
# 179 0 1
# 177 0 1
# 173 0 1
# 169 0 1
# 163 0 1
# 160 0 1
# 157 0 1
# 153 0 1
# 152 0 1
# 145 0 1
# 142 0 1
# 136 0 1
# 135 0 1
# 131 0 1
# 128 0 1
# 127 0 1
# 124 0 1
# 124 0 1
# 121 0 1
# 118 0 1
# 115 0 1
# 111 0 1
# 110 0 1
# 108 0 1
# 103 0 1
# 99 0 1
# 97 0 1
# 96 0 1
# 94 0 1
# 90 0 1
# 88 0 1
# 87 0 1
# 86 0 1
# 85 1 1
# 83 1 1
# 82 1 1
# 82 1 1
# 81 1 1
# 81 1 1
# 83 1 1
# 85 1 1
# 87 0 2
# 88 0 2
# 90 0 2
# 93 0 2
# 97 0 2
# 100 0 2
# 107 0 2
# 110 0 2
# 116 0 2
# 121 0 2
# 123 0 2
# 126 0 2
# 128 0 2
# 133 0 2
# 135 0 2
# 142 0 2
# 147 0 2
# 151 0 2
# 155 0 2
# 155 0 2
# 159 0 2
# 163 0 2
# 168 0 2
# 170 0 2
# 172 0 2
# 175 0 2
# 176 0 2
# 177 0 2
# 179 0 2
# 179 0 2
# 177 0 2
# 177 0 2
# 177 0 2
# 177 0 2
# 177 0 2
# 177 0 2
# 177 0 2
# 176 0 2
# 176 0 2
# 178 0 2
# 178 0 2
# 178 0 2
# 179 0 2
# 178 0 2
# 175 0 2
# 168 0 2
# 162 0 2
# 159 0 2
# 156 0 2
# 154 0 2
# 150 0 2
# 145 0 2
# 140 0 2
# 139 0 2
# 135 0 2
# 133 0 2
# 129 0 2
# 127 0 2
# 123 0 2
# 123 0 2
# 119 0 2
# 116 0 2
# 112 0 2
# 110 0 2
# 110 0 2
# 107 0 2
# 104 0 2
# 101 0 2
# 99 0 2
# 96 0 2
# 97 0 2
# 94 0 2
# 90 0 2
# 88 0 2
# 88 0 2
# 86 0 2
# 86 0 2
# 85 1 2
# 82 1 2
# 81 1 2
# 81 1 2
# 80 1 2
# 80 1 2
# 80 1 2
# 80 1 2
# 80 1 2
# 82 1 2
# 82 1 2
# 85 1 2
# 88 0 3
# 89 0 3
# 89 0 3
# 97 0 3
# 99 0 3
# 102 0 3
# 107 0 3
# 112 0 3
# 115 0 3
# 116 0 3
# 120 0 3
# 124 0 3
# 126 0 3
# 127 0 3
# 131 0 3
# 135 0 3
# 137 0 3
# 142 0 3
# 145 0 3
# 148 0 3
# 152 0 3
# 154 0 3
# 158 0 3
# 159 0 3
# 165 0 3
# 169 0 3
# 171 0 3
# 172 0 3
# 174 0 3
# 174 0 3
# 175 0 3
# 175 0 3
# 176 0 3
# 176 0 3
# 178 0 3
# 178 0 3
# 179 0 3
# 179 0 3
# 179 0 3
# 179 0 3
# 179 0 3
# 178 0 3
# 178 0 3
# 178 0 3
# 178 0 3
# 178 0 3
# 178 0 3
# 178 0 3
# 178 0 3
# 178 0 3
# 177 0 3
# 177 0 3
# 177 0 3
# 178 0 3
# 177 0 3
# 176 0 3
# 177 0 3
# 176 0 3
# 176 0 3
# 175 0 3
# 173 0 3
# 172 0 3
# 173 0 3
# 175 0 3
# 176 0 3
# 173 0 3
# 172 0 3
# 171 0 3
# 171 0 3
# 171 0 3
# 171 0 3
# 172 0 3
# 174 0 3
# 174 0 3
# 175 0 3
# 176 0 3
# 175 0 3
# 175 0 3
# 174 0 3
# 174 0 3
# 174 0 3
# 174 0 3
# 174 0 3
# 174 0 3
# 174 0 3
# 174 0 3
# 174 0 3
# 174 0 3
# 173 0 3
# 174 0 3

# %%
plt.plot(angles_list)

# %%
len(avg_angles)
# Out:
# 15

# %%
min(angles_list)
# Out:
# 80

# %%
max(angles_list)
# Out:
# 180

# %%
x=np.array(angles_list)-85

# %%
x=x/85

# %%
x=np.abs(x-1)*100

# %%
plt.plot(angles_list)
plt.plot(x)
plt.show()

# %%
avg_angles=[]
for i in range(0,len(angles_list)//5,5):
  avg_angles.append(np.mean(angles_list[i:i+5]))
plt.plot(avg_angles)

# %%
len(angles_list)
# Out:
# 359

# %% [markdown]
# COUNTING REPS BASED ON THRESHOLD

# %%
counter=0
prev_check=0

for i in x:
  pos = 1 if i >= 50 else 0
  if prev_check - pos == 1:
    counter +=1
  prev_check = pos

# %%
counter
