# %%
import os
import numpy as np
import json
import matplotlib.pyplot as plt
from scipy import ndimage

# %%
folder_path='/content/drive/MyDrive/keypoints_from_videos_json/lunge/'

# %%
def angle_between_points(a, b, c):

    a = np.array(a)
    b = np.array(b)
    c = np.array(c)
    ba = a - b
    bc = c - b

    cosine_angle = np.dot(ba, bc) / (np.linalg.norm(ba) * np.linalg.norm(bc))
    angle = np.arccos(cosine_angle)

    return np.degrees(angle)

# %%
#check for width and height should be multiple of 16

count_of_squats = 0
squat_pos = 0
prev_squat_pos = 0
angles_list=[]
# i = 0
for json_file in os.listdir(folder_path):
  # print(json_file)
  f=open(folder_path+json_file,)
  raw_json=json.load(f)
  x=list(raw_json.items())[1][1][0]['pose_keypoints_2d']
  x=np.array(x).reshape(18,3)
  # print(x)
  f.close()
  try:
    # calculate left leg angle
    center_11=int(x[11][0]),int(x[11][1])#left hip value
    center_12=int(x[12][0]),int(x[12][1])#left knee value
    center_13=int(x[13][0]),int(x[13][1])#left ankle value

    #check for squat
    squat_left_angle = int(angle_between_points(center_11, center_12, center_13))
    
    squat_pos = 1 if squat_left_angle <= 110 else 0
    if prev_squat_pos - squat_pos == 1:
      count_of_squats +=1

    prev_squat_pos = squat_pos

    print(squat_left_angle, squat_pos, count_of_squats)

    angles_list.append(squat_left_angle)
  except:
    pass
# Out:
# 173 0 0
# 173 0 0
# 172 0 0
# 172 0 0
# 172 0 0
# 172 0 0
# 173 0 0
# 174 0 0
# 174 0 0
# 174 0 0
# 174 0 0
# 173 0 0
# 173 0 0
# 173 0 0
# 173 0 0
# 174 0 0
# 173 0 0
# 172 0 0
# 172 0 0
# 174 0 0
# 173 0 0
# 174 0 0
# 173 0 0
# 174 0 0
# 176 0 0
# 176 0 0
# 176 0 0
# 175 0 0
# 178 0 0
# 178 0 0
# 179 0 0
# 177 0 0
# 171 0 0
# 162 0 0
# 148 0 0
# 142 0 0
# 136 0 0
# 133 0 0
# 138 0 0
# 145 0 0
# 151 0 0
# 159 0 0
# 165 0 0
# 170 0 0
# 177 0 0
# 179 0 0
# 179 0 0
# 179 0 0
# 179 0 0
# 174 0 0
# 175 0 0
# 173 0 0
# 166 0 0
# 160 0 0
# 154 0 0
# 153 0 0
# 144 0 0
# 143 0 0
# 141 0 0
# 134 0 0
# 133 0 0
# 129 0 0
# 123 0 0
# 119 0 0
# 117 0 0
# 111 0 0
# 103 1 0
# 98 1 0
# 96 1 0
# 90 1 0
# 82 1 0
# 78 1 0
# 76 1 0
# 73 1 0
# 71 1 0
# 70 1 0
# 70 1 0
# 70 1 0
# 68 1 0
# 68 1 0
# 68 1 0
# 68 1 0
# 68 1 0
# 70 1 0
# 71 1 0
# 71 1 0
# 74 1 0
# 78 1 0
# 84 1 0
# 87 1 0
# 89 1 0
# 95 1 0
# 99 1 0
# 104 1 0
# 108 1 0
# 115 0 1
# 119 0 1
# 128 0 1
# 136 0 1
# 148 0 1
# 153 0 1
# 164 0 1
# 177 0 1
# 176 0 1
# 177 0 1
# 166 0 1
# 168 0 1
# 162 0 1
# 164 0 1
# 154 0 1
# 157 0 1
# 150 0 1
# 153 0 1
# 154 0 1
# 154 0 1
# 158 0 1
# 163 0 1
# 175 0 1
# 172 0 1
# 175 0 1
# 176 0 1
# 175 0 1
# 173 0 1
# 173 0 1
# 174 0 1
# 173 0 1
# 173 0 1
# 173 0 1
# 173 0 1
# 173 0 1
# 173 0 1
# 173 0 1
# 173 0 1
# 173 0 1
# 175 0 1
# 175 0 1
# 175 0 1
# 175 0 1
# 175 0 1
# 175 0 1
# 175 0 1
# 177 0 1
# 176 0 1
# 179 0 1
# 178 0 1
# 177 0 1
# 174 0 1
# 167 0 1
# 177 0 1
# 174 0 1
# 178 0 1
# 178 0 1
# 178 0 1
# 179 0 1
# 176 0 1
# 173 0 1
# 174 0 1
# 175 0 1
# 176 0 1
# 178 0 1
# 178 0 1
# 171 0 1
# 172 0 1
# 173 0 1
# 173 0 1
# 177 0 1
# 173 0 1
# 168 0 1
# 172 0 1
# 165 0 1
# 160 0 1
# 162 0 1
# 161 0 1
# 158 0 1
# 154 0 1
# 149 0 1
# 144 0 1
# 143 0 1
# 140 0 1
# 128 0 1
# 126 0 1
# 120 0 1
# 112 0 1
# 107 1 1
# 101 1 1
# 98 1 1
# 93 1 1
# 89 1 1
# 84 1 1
# 86 1 1
# 86 1 1
# 85 1 1
# 83 1 1
# 78 1 1
# 76 1 1
# 78 1 1
# 76 1 1
# 75 1 1
# 76 1 1
# 75 1 1
# 72 1 1
# 73 1 1
# 77 1 1
# 78 1 1
# 81 1 1
# 81 1 1
# 80 1 1
# 86 1 1
# 91 1 1
# 92 1 1
# 99 1 1
# 100 1 1
# 100 1 1
# 108 1 1
# 115 0 2
# 114 0 2
# 122 0 2
# 130 0 2
# 127 0 2
# 133 0 2
# 135 0 2
# 138 0 2
# 142 0 2
# 146 0 2
# 146 0 2
# 151 0 2
# 157 0 2
# 158 0 2
# 166 0 2
# 170 0 2
# 173 0 2
# 171 0 2
# 174 0 2
# 164 0 2
# 173 0 2
# 173 0 2
# 170 0 2
# 175 0 2
# 179 0 2
# 179 0 2
# 177 0 2
# 178 0 2
# 173 0 2
# 174 0 2
# 173 0 2
# 176 0 2
# 179 0 2
# 178 0 2
# 177 0 2
# 176 0 2
# 175 0 2
# 174 0 2
# 174 0 2
# 174 0 2
# 172 0 2
# 172 0 2
# 173 0 2
# 174 0 2
# 174 0 2
# 174 0 2
# 174 0 2
# 174 0 2
# 174 0 2
# 174 0 2
# 173 0 2
# 173 0 2
# 173 0 2
# 174 0 2
# 174 0 2
# 174 0 2
# 174 0 2
# 173 0 2
# 172 0 2
# 171 0 2
# 172 0 2
# 171 0 2
# 171 0 2
# 171 0 2
# 172 0 2
# 172 0 2
# 172 0 2
# 171 0 2

# %%
plt.plot(angles_list)

# %%
#check for width and height should be multiple of 16

count_of_squats = 0
squat_pos = 0
prev_squat_pos = 0
r_angles_list=[]
# i = 0
for json_file in os.listdir(folder_path):
  # print(json_file)
  f=open(folder_path+json_file,)
  raw_json=json.load(f)
  x=list(raw_json.items())[1][1][0]['pose_keypoints_2d']
  x=np.array(x).reshape(18,3)
  # print(x)
  f.close()
  try:
    # calculate left leg angle
    # center_11=int(x[11][0]*1920),int(x[11][1]*1080)#left hip value
    # center_12=int(x[12][0]*1920),int(x[12][1]*1080)#left knee value
    # center_13=int(x[13][0]*1920),int(x[13][1]*1080)#left ankle value
    center_8=int(x[8][0]),int(x[8][1])#left hip value
    center_9=int(x[9][0]),int(x[9][1])#left knee value
    center_10=int(x[10][0]),int(x[10][1])#left ankle value

    #check for squat
    squat_right_angle = int(angle_between_points(center_8, center_9, center_10))
    
    squat_pos = 1 if squat_right_angle <= 110 else 0
    if prev_squat_pos - squat_pos == 1:
      count_of_squats +=1

    prev_squat_pos = squat_pos

    print(squat_right_angle, squat_pos, count_of_squats)

    r_angles_list.append(squat_right_angle)
  except:
    pass
# Out:
# 177 0 0
# 177 0 0
# 177 0 0
# 177 0 0
# 177 0 0
# 177 0 0
# 177 0 0
# 177 0 0
# 177 0 0
# 177 0 0
# 177 0 0
# 177 0 0
# 179 0 0
# 179 0 0
# 179 0 0
# 178 0 0
# 178 0 0
# 178 0 0
# 178 0 0
# 178 0 0
# 178 0 0
# 178 0 0
# 178 0 0
# 179 0 0
# 176 0 0
# 178 0 0
# 178 0 0
# 179 0 0
# 176 0 0
# 176 0 0
# 173 0 0
# 172 0 0
# 172 0 0
# 171 0 0
# 171 0 0
# 171 0 0
# 170 0 0
# 171 0 0
# 171 0 0
# 169 0 0
# 166 0 0
# 163 0 0
# 162 0 0
# 163 0 0
# 159 0 0
# 154 0 0
# 155 0 0
# 158 0 0
# 153 0 0
# 154 0 0
# 155 0 0
# 150 0 0
# 152 0 0
# 151 0 0
# 152 0 0
# 147 0 0
# 145 0 0
# 144 0 0
# 143 0 0
# 137 0 0
# 137 0 0
# 131 0 0
# 125 0 0
# 115 0 0
# 113 0 0
# 106 1 0
# 100 1 0
# 98 1 0
# 94 1 0
# 91 1 0
# 85 1 0
# 85 1 0
# 80 1 0
# 77 1 0
# 78 1 0
# 78 1 0
# 77 1 0
# 76 1 0
# 76 1 0
# 76 1 0
# 76 1 0
# 76 1 0
# 76 1 0
# 76 1 0
# 77 1 0
# 77 1 0
# 78 1 0
# 83 1 0
# 84 1 0
# 85 1 0
# 88 1 0
# 88 1 0
# 90 1 0
# 97 1 0
# 98 1 0
# 103 1 0
# 106 1 0
# 106 1 0
# 115 0 1
# 115 0 1
# 124 0 1
# 124 0 1
# 133 0 1
# 137 0 1
# 138 0 1
# 144 0 1
# 145 0 1
# 145 0 1
# 156 0 1
# 157 0 1
# 158 0 1
# 162 0 1
# 165 0 1
# 166 0 1
# 168 0 1
# 171 0 1
# 174 0 1
# 177 0 1
# 178 0 1
# 177 0 1
# 178 0 1
# 178 0 1
# 178 0 1
# 177 0 1
# 177 0 1
# 178 0 1
# 175 0 1
# 175 0 1
# 176 0 1
# 174 0 1
# 175 0 1
# 174 0 1
# 174 0 1
# 176 0 1
# 176 0 1
# 177 0 1
# 179 0 1
# 178 0 1
# 178 0 1
# 177 0 1
# 174 0 1
# 174 0 1
# 172 0 1
# 173 0 1
# 165 0 1
# 158 0 1
# 157 0 1
# 147 0 1
# 137 0 1
# 133 0 1
# 127 0 1
# 133 0 1
# 132 0 1
# 140 0 1
# 150 0 1
# 154 0 1
# 160 0 1
# 167 0 1
# 172 0 1
# 172 0 1
# 172 0 1
# 179 0 1
# 175 0 1
# 174 0 1
# 179 0 1
# 174 0 1
# 172 0 1
# 173 0 1
# 164 0 1
# 168 0 1
# 164 0 1
# 160 0 1
# 161 0 1
# 155 0 1
# 151 0 1
# 150 0 1
# 143 0 1
# 137 0 1
# 135 0 1
# 128 0 1
# 123 0 1
# 121 0 1
# 115 0 1
# 107 1 1
# 106 1 1
# 102 1 1
# 97 1 1
# 91 1 1
# 87 1 1
# 87 1 1
# 85 1 1
# 82 1 1
# 80 1 1
# 78 1 1
# 76 1 1
# 74 1 1
# 76 1 1
# 74 1 1
# 73 1 1
# 75 1 1
# 74 1 1
# 74 1 1
# 76 1 1
# 78 1 1
# 82 1 1
# 87 1 1
# 92 1 1
# 93 1 1
# 98 1 1
# 104 1 1
# 110 1 1
# 115 0 2
# 120 0 2
# 125 0 2
# 131 0 2
# 135 0 2
# 143 0 2
# 146 0 2
# 152 0 2
# 154 0 2
# 165 0 2
# 169 0 2
# 168 0 2
# 163 0 2
# 163 0 2
# 156 0 2
# 146 0 2
# 142 0 2
# 135 0 2
# 128 0 2
# 125 0 2
# 129 0 2
# 136 0 2
# 149 0 2
# 158 0 2
# 161 0 2
# 169 0 2
# 171 0 2
# 172 0 2
# 174 0 2
# 179 0 2
# 180 0 2
# 179 0 2
# 178 0 2
# 178 0 2
# 178 0 2
# 177 0 2
# 176 0 2
# 175 0 2
# 175 0 2
# 174 0 2
# 174 0 2
# 174 0 2
# 174 0 2
# 174 0 2
# 174 0 2
# 174 0 2
# 175 0 2
# 175 0 2
# 175 0 2
# 175 0 2
# 175 0 2
# 176 0 2
# 176 0 2
# 177 0 2
# 177 0 2
# 177 0 2
# 177 0 2
# 177 0 2
# 178 0 2
# 178 0 2
# 177 0 2
# 178 0 2
# 178 0 2
# 178 0 2
# 178 0 2
# 178 0 2
# 178 0 2
# 178 0 2
# 178 0 2
# 178 0 2
# 178 0 2

# %%
plt.plot(r_angles_list)

# %%
len(avg_angles)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-3164d932a378> in <module>()
# ----> 1 len(avg_angles)
#
# NameError: name 'avg_angles' is not defined

# %%
min(angles_list)

# %%
max(angles_list)

# %%
# #score calculation
# x=np.array(angles_list)-135
# x=x/135
# x=np.abs(x-1)*100

# %%
plt.plot(angles_list)
plt.plot(x)
plt.show()

# %%
len(angles_list)

# %% [markdown]
# COUNTING REPS BASED ON THRESHOLD

# %%
counter=0
prev_check=0

for i in x:
  pos = 1 if i >= 50 else 0
  if prev_check - pos == 1:
    counter +=1
  prev_check = pos

# %%
counter

# %%
avg_angles=[]
for i in range(0,len(angles_list)//5,5):
  avg_angles.append(np.mean(angles_list[i:i+5]))
plt.plot(avg_angles)
