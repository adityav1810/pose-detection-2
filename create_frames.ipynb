# %%
import numpy as np
import json 
import os
import cv2
from google.colab.patches import cv2_imshow
import shutil

# %%
import cv2
import time
import os

def video_to_frames(input_loc, output_loc):
    """Function to extract frames from input video file
    and save them as separate frames in an output directory.
    Args:
        input_loc: Input video file.
        output_loc: Output directory to save the frames.
    Returns:
        None
    """
    try:
        os.mkdir(output_loc)
    except OSError:
        pass
    # Log the time
    time_start = time.time()
    # Start capturing the feed
    cap = cv2.VideoCapture(input_loc)
    # Find the number of frames
    video_length = int(cap.get(cv2.CAP_PROP_FRAME_COUNT)) - 1
    print ("Number of frames: ", video_length)
    count = 0
    print ("Converting video..\n")
    # Start converting the video
    while cap.isOpened():
        # Extract the frame
        ret, frame = cap.read()
        # Write the results back to output location.
        cv2.imwrite(output_loc + "/%#05d.jpg" % (count+1), frame)
        count = count + 1
        # If there are no more frames left
        if (count > (video_length-1)):
            # Log the time again
            time_end = time.time()
            # Release the feed
            cap.release()
            # Print stats
            print ("Done extracting frames.\n%d frames extracted" % count)
            print ("It took %d seconds forconversion." % (time_end-time_start))
            break

if __name__=="__main__":

    names=['277675946', '277674569', '277675122', '276488903', '277675723']
    for name in names:
      print(name)
      input_loc = '/content/drive/MyDrive/Videos/'+name+'.mp4'
      output_loc = '/content/'+name+'/'
      video_to_frames(input_loc, output_loc)
      shutil.make_archive(name, 'zip', '/content/'+name)
# Out:
# 277675946
# Number of frames:  367
# Converting video..
#
# Done extracting frames.
# 367 frames extracted
# It took 13 seconds forconversion.
# 277674569
# Number of frames:  358
# Converting video..
#
# Done extracting frames.
# 358 frames extracted
# It took 13 seconds forconversion.
# 277675122
# Number of frames:  281
# Converting video..
#
# Done extracting frames.
# 281 frames extracted
# It took 10 seconds forconversion.
# 276488903
# Number of frames:  320
# Converting video..
#
# Done extracting frames.
# 320 frames extracted
# It took 12 seconds forconversion.
# 277675723
# Number of frames:  363
# Converting video..
#
# Done extracting frames.
# 363 frames extracted
# It took 14 seconds forconversion.
